# %%
# %matplotlib inline
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
tweets_data_path = 'twitter_data.txt'
tweets_data = []
tweets_file = open(tweets_data_path,'r')
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

# %%
tweets_data[:1]
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Mar 03 23:37:58 +0000 2017',
#   'display_text_range': [9, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 157398659,
#      'id_str': '157398659',
#      'indices': [0, 8],
#      'name': 'Nathan Hale',
#      'screen_name': 'NH92276'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 837809303935410177,
#   'id_str': '837809303935410177',
#   'in_reply_to_screen_name': 'NH92276',
#   'in_reply_to_status_id': 837807251737960449,
#   'in_reply_to_status_id_str': '837807251737960449',
#   'in_reply_to_user_id': 157398659,
#   'in_reply_to_user_id_str': '157398659',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
# ...

# %%
adj_df = pd.DataFrame()

adj_df['lang'] = df['lang']
adj_df['text'] = df['text']

# %%
adj_df['geo'] = df['geo']

# %%
adj_df[:5]
# Out:
#   lang                                               text   geo
# 0   en  @NH92276 as they should, trump and putin, russ...  None
# 1   en  RT @riotwomennn: Trump watching Fox News? Ralp...  None
# 2   en  Breaking News.  "Donald Trump arrested"   Plea...  None
# 3   en  Just Cheeto Head swinging in the breeze https:...  None
# 4   en  RT @TheDailyEdge: The leaks become a shower: B...  None

# %%
#Tweets by language bar chart
tweets_by_lang = adj_df['lang'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Langauges', fontsize=15)
ax.set_ylabel('Number of tweets', fontsize=15)
ax.set_title('Top 5 langauges', fontsize=15, fontweight='bold')
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')

# %%
df['place'][:5]
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: place, dtype: object

# %%
val = []
for locs in df['place']:
    val.append(str(locs))

print(val)
# Out:
# ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'nan', 'nan', 'None', 'None', 'None', 'nan', 'None', 'None', 'None', 'None', 'nan', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'nan', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'N
# ...

# %%
print(len(val))
# Out:
# 39866

# %%
adj_df['location'] = val

# %%
adj_df['location'].value_counts()
# Out:
# None                                                                                                                                                                                                                                                                                                                                                                                                              37549
# nan                                                                                                                                                                                                                                                                                                                                                                                                                1917
# ...

# %%
vals = []

for cors in df['coordinates']:
    vals.append(str(cors))

adj_df['coords'] = vals

# %%
adj_df['coords'].value_counts()
# Out:
# None                                                              37939
# nan                                                                1917
# {'type': 'Point', 'coordinates': [-84.74752, 42.24623]}               2
# {'type': 'Point', 'coordinates': [-77.0276216, 38.8940974]}           1
# {'type': 'Point', 'coordinates': [-84.7533, 42.2467]}                 1
# {'type': 'Point', 'coordinates': [-118.24790955, 33.97866994]}        1
# {'type': 'Point', 'coordinates': [-76.51755509, 39.12202696]}         1
# {'type': 'Point', 'coordinates': [-76.51767325, 39.12194573]}         1
# {'type': 'Point', 'coordinates': [-87.90968018, 43.04137104]}         1
# {'type': 'Point', 'coordinates': [-87.62626724, 41.88804564]}         1
# {'type': 'Point', 'coordinates': [-117.16627197, 32.7143122]}         1
# Name: coords, dtype: int64
